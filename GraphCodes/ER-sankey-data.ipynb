# %%
from adblockparser import AdblockRules
import tldextract
import re
import collections
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.sankey import Sankey
from ipysankeywidget import SankeyWidget
from ipywidgets import Layout


partner_dictionary = {}

def adblockparser_parse(rule_list):
    return AdblockRules(rule_list)

def return_domain(rule_line):
    rule = []
    rule.append(rule_line)
    easylist_adblock_rules = adblockparser_parse(rule)
    domain = ''

    # print("rule list ----->", rule)
    # print("Value of r ---->", easylist_adblock_rules.rules)
    for r in easylist_adblock_rules.rules:
        y = r.rule_text
        x = y
        if x[:2] == '||':
            if '^' in x:
                split = x.index("^")
                x = x[2:split]
            else:
                x = x[2:]
        elif x[:1] =='|':
            x = x[1:]

        # print("from return domain -->",x)
        domain = tldextract.extract(x).domain

    return domain

def check_if_valid_domain(hostname):
    if len(hostname) > 255:
        return False
    hostname = hostname.rstrip(".")
    allowed = re.compile('^[a-z0-9]([a-z0-9\-\_]{0,61}[a-z0-9])?$',
                         re.IGNORECASE)
    labels = hostname.split(".")

    # the TLD must not be all-numeric
    if re.match(r"^[0-9]+$", labels[-1]):
        return False

    return all(allowed.match(x) for x in labels)

def extract_partner_domain():

    global partner_dictionary
    partner_count = 0

    with open('processed-dec-2019-exceptionrules-latest.txt') as fexception:
        partner = ''
        domain=''
        for line in fexception:
            # print(line)
            line = line.rstrip()

            if line[0] == '[':
                partner = line[1:-1]
                if partner not in partner_dictionary.keys():
                    partner_dictionary.update({partner:{'collaborators':[],'surrogate':[]}})
                    partner_count +=1

            if 'sitekey' in line:
                split = line.index("sitekey")
                line = line[:split]
                # print("Line cut 1--->",line)
                if line[-1] == '$' or line[-1] ==',':
                    line = line[:-1]
                # print("Line cut 2---->",line)

            if '#@#' or '###' in line:
                split=-1
                if '#@#' in line:
                    split = line.index("#@#")
                if '###' in line:
                    split = line.index("###")

                if split !=0:
                    line = line[:split]
                    # print("Line cut 3--->",line)

            if line[0] != '[':
                domain = return_domain(line)
                if check_if_valid_domain(domain) == False:
                    continue
                else:
                    partner_dictionary[partner]['collaborators'].append(domain)


            if line.find("$") >= 0 and partner != '':
                if (check_if_valid_domain(return_domain(line))) != False:
                    option_separator_index = line.find("$")
                    options_list = line[option_separator_index + 1:]
                    while options_list != "":
                        option_full = ""
                        split = options_list.index(",") if "," in options_list else -1
                        if split == -1:
                            option_full = options_list
                            options_list = ""
                        else:
                            option_full = options_list[:split]

                        list_exists = option_full.index("=") if "=" in option_full else -1

                        # case when lists are present - domain, sitekey cases
                        if list_exists != -1:
                            option_name = option_full[:list_exists]
                            # print("options_name -->"+option_name)
                            if option_name == 'domain':
                                option_full = option_full[list_exists + 1:]
                                while option_full != "":
                                    next_index = option_full.index("|") if "|" in option_full else -1

                                    # case when there are no more lists present
                                    if next_index == -1:
                                        # print(option_full)
                                        if option_full[0] == '~':
                                                option_full=option_full[1:]
                                                partner_dictionary[partner]['surrogate'].append(return_domain(option_full))
                                        else:
                                            partner_dictionary[partner]['surrogate'].append(return_domain(option_full))

                                        option_full = ""

                                    # case when there are options present in list
                                    else:

                                        curr_option = option_full[:next_index]
                                        if curr_option[0] == '~':
                                            curr_option = curr_option[1:]
                                            partner_dictionary[partner]['surrogate'].append(return_domain(curr_option))
                                        else:
                                            partner_dictionary[partner]['surrogate'].append(return_domain(curr_option))
                                        option_full = option_full[next_index + 1:]

                        options_list = options_list[split + 1:]
                        
extract_partner_domain()

    # print(partner_dictionary)

    # with open('partner-collaborator.txt','w') as f:
    #     for partner,partner_details in partner_dictionary.items():
    #         f.write('partner------>'+partner)
    #         f.write('\n')
    #         for partner_type ,partner_list in partner_details.items():
    #             f.write("partner type ----->"+partner_type)
    #             for item in partner_list:
    #                 f.write('\n')
    #                 f.write(item)
    #             f.write('\n')

# %%
# the following doesnt give the graph but runs successfully, debug later
layout = Layout(width="300", height="200")
def sankey(margin_top=10, **value):
    """Show SankeyWidget with default values for size and margins"""
    return SankeyWidget(layout=layout,
                        margins=dict(top=margin_top, bottom=0, left=30, right=60),
                        **value)

# %%
# get the data to plot it in javascript and display in the html file attached as ER-sankey-generation
def graph_get_data():
    global partner_dictionary 
    
    l=[]
    for key in partner_dictionary.keys():
        l.extend(partner_dictionary[key]['collaborators'])

    w = collections.Counter(l)

    w_dup ={}

    listofTuples = sorted(w.items(), key=lambda x: x[1], reverse=True)

    for elem in listofTuples:
        if elem[1] >10:
            w_dup.update({elem[0]:elem[1]})
            
    top_collab=[]
    i=0
    for key in w_dup.keys():
        if i == 5:
            break
        top_collab.append(key)
        i+=1
        
#     print(top_collab)

    sankey_data ={}
    for item in top_collab:
        sankey_data.update({item:[]})
        
#     print(sankey_data)

    for key in partner_dictionary.keys():
        for collab in top_collab:
            cnt = partner_dictionary[key]['collaborators'].count(collab)
            if cnt >0:
                sankey_data[collab].append({key:cnt})
    
#     print(sankey_data)

    sankey_links = []
    
    for key in sankey_data.keys():
        for item in sankey_data[key]:
            for partner in item.keys():
                link={}
                link = {'source':key, 'target':partner, 'value':item[partner]}
                sankey_links.append(link)
                
#     print(sankey_links)
    for elem in sankey_links:
        print('[\'',elem['source'],'\',\'',elem['target'],'\',',elem['value'],'],')


    
    
    layout = Layout(width="300", height="200")
    SankeyWidget(links=sankey_links, layout=layout).auto_save_png('test.png')
    
graph_get_data()
# Out:
# [' google ',' netzwelt.de ', 2 ],
# [' google ',' Sedo ', 1 ],
# [' google ',' 1und1 Mail und Media GmbH ', 6 ],
# [' google ',' Renego ', 3 ],
# [' google ',' izito.com ', 5 ],
# [' google ',' Vysimo ', 8 ],
# [' google ',' Leaf Group Ltd. ', 5 ],
# [' google ',' chip.de ', 4 ],
# [' google ',' Opendi AG ', 4 ],
# [' google ',' Cylex ', 4 ],
# [' google ',' winfuture.de ', 3 ],
# [' google ',' ParkingCrew ', 1 ],
# [' google ',' Digimedia ', 1 ],
# [' google ',' media.net ', 1 ],
# [' google ',' System1 Search ', 4 ],
# [' google ',' System1 parking ', 1 ],
# [' google ',' Ennovative ', 1 ],
# [' google ',' Bodis ', 1 ],
# [' google ',' Netsphere ', 2 ],
# [' google ',' Google ', 1711 ],
# [' google ',' Tradedoubler ', 2 ],
# [' doubleclick ',' netzwelt.de ', 3 ],
# [' doubleclick ',' BuySellAds ', 2 ],
# [' doubleclick ',' heise.de ', 2 ],
# [' doubleclick ',' StandS4 ', 1 ],
# [' doubleclick ',' SimilarGroup ', 6 ],
# [' doubleclick ',' Chitika ', 1 ],
# [' doubleclick ',' Leaf Group Ltd. ', 30 ],
# [' doubleclick ',' Recycled Mistakes ', 1 ],
# [' doubleclick ',' Reddit.com ', 1 ],
# [' doubleclick ',' Opendi AG ', 5 ],
# [' doubleclick ',' wg-gesucht.de ', 1 ],
# [' doubleclick ',' droidmid.com.ua ', 1 ],
# [' doubleclick ',' jakubmarian.com ', 1 ],
# [' doubleclick ',' catzware.com ', 1 ],
# [' doubleclick ',' Cylex ', 14 ],
# [' doubleclick ',' reawakens.net ', 2 ],
# [' doubleclick ',' rctgo.com ', 2 ],
# [' doubleclick ',' events12.com ', 2 ],
# [' doubleclick ',' tsvbodnegg.de ', 1 ],
# [' doubleclick ',' tools4free.eu ', 2 ],
# [' doubleclick ',' computerbase.de ', 9 ],
# [' doubleclick ',' spotsify.com ', 4 ],
# [' doubleclick ',' code-reference.com ', 1 ],
# [' doubleclick ',' blogginger.de ', 1 ],
# [' doubleclick ',' eaveselectrical.co.uk ', 1 ],
# [' doubleclick ',' pdasite.pl ', 4 ],
# [' doubleclick ',' innenaussen.com ', 1 ],
# [' doubleclick ',' tabletsbaratas.net ', 1 ],
# [' doubleclick ',' blogdemigueldiaz.com ', 1 ],
# [' doubleclick ',' e-cougar.fr ', 1 ],
# [' doubleclick ',' olek.tk ', 1 ],
# [' doubleclick ',' yourlaws.ca ', 1 ],
# [' doubleclick ',' strickmuehle.com ', 1 ],
# [' doubleclick ',' GoDaddy Parking ', 1 ],
# [' doubleclick ',' spielwiki.de ', 1 ],
# [' doubleclick ',' animeblogreviews.com ', 2 ],
# [' doubleclick ',' isitup.org ', 1 ],
# [' doubleclick ',' rex4.com ', 1 ],
# [' doubleclick ',' fastquake.com ', 2 ],
# [' doubleclick ',' Onet.pl ', 4 ],
# [' doubleclick ',' mordudejeux.com ', 4 ],
# [' doubleclick ',' hackthis.co.uk ', 3 ],
# [' doubleclick ',' etymonline.com ', 3 ],
# [' doubleclick ',' compactlaw.co.uk ', 3 ],
# [' doubleclick ',' pagewizz.com ', 2 ],
# [' doubleclick ',' coonplace.ru ', 3 ],
# [' doubleclick ',' juradmin.com ', 1 ],
# [' doubleclick ',' homework.net.ua ', 2 ],
# [' doubleclick ',' yourepetir.com ', 1 ],
# [' doubleclick ',' Wikihoops.com ', 1 ],
# [' doubleclick ',' Chip.de ', 8 ],
# [' doubleclick ',' jubiley.ru ', 1 ],
# [' doubleclick ',' Inodroid.ru ', 2 ],
# [' doubleclick ',' And.ck.ua ', 1 ],
# [' doubleclick ',' tweakguides.com ', 1 ],
# [' doubleclick ',' Fanorg.net ', 1 ],
# [' doubleclick ',' Rezepte-cocktails.de ', 2 ],
# [' doubleclick ',' ekant.ru ', 2 ],
# [' doubleclick ',' seoslim.ru ', 1 ],
# [' doubleclick ',' inside11.de ', 1 ],
# [' doubleclick ',' yak-zrobyty ', 1 ],
# [' doubleclick ',' chaype.ru ', 1 ],
# [' doubleclick ',' ried.cl ', 1 ],
# [' doubleclick ',' monsterreport.de ', 2 ],
# [' doubleclick ',' cardfight.ru ', 1 ],
# [' doubleclick ',' webdesigner-tutorials.de ', 2 ],
# [' doubleclick ',' anglissime.com ', 4 ],
# [' doubleclick ',' payzle.com ', 2 ],
# [' doubleclick ',' mijnkapitaal.be ', 4 ],
# [' doubleclick ',' Reverso ', 5 ],
# [' doubleclick ',' Binder und Grusdat GbR ', 2 ],
# [' doubleclick ',' booksshouldbefree.com ', 1 ],
# [' doubleclick ',' Outbrain ', 3 ],
# [' doubleclick ',' medspecial.ru ', 3 ],
# [' doubleclick ',' Digimedia ', 1 ],
# [' doubleclick ',' t4mag.com ', 3 ],
# [' doubleclick ',' popculture-y.com ', 5 ],
# [' doubleclick ',' pkmn.net ', 1 ],
# [' doubleclick ',' flying-news.com ', 1 ],
# [' doubleclick ',' uninst.ru ', 1 ],
# [' doubleclick ',' for-androidos.com ', 2 ],
# [' doubleclick ',' 100cards.ru ', 2 ],
# [' doubleclick ',' gdziezjesc.info ', 1 ],
# [' doubleclick ',' teneriffa-news.com ', 1 ],
# [' doubleclick ',' math1.ru ', 1 ],
# [' doubleclick ',' nikkomania.com ', 3 ],
# [' doubleclick ',' t3n.de ', 1 ],
# [' doubleclick ',' senseyeesports.com ', 4 ],
# [' doubleclick ',' 101sovet.ucoz.net ', 1 ],
# [' doubleclick ',' CCM Benchmark Group ', 17 ],
# [' doubleclick ',' Gamer Network ', 4 ],
# [' doubleclick ',' videoquality.pl ', 2 ],
# [' doubleclick ',' nazwiska-polskie.pl ', 1 ],
# [' doubleclick ',' grobmeier.de ', 2 ],
# [' doubleclick ',' allanekdot.ru ', 1 ],
# [' doubleclick ',' thenoob.net ', 2 ],
# [' doubleclick ',' mrkmg.com ', 2 ],
# [' doubleclick ',' diary.anek.ws ', 3 ],
# [' doubleclick ',' Taboola ', 6 ],
# [' doubleclick ',' cyfrowydoradca.pl ', 2 ],
# [' doubleclick ',' doorinworld.ru ', 2 ],
# [' doubleclick ',' Mered.de ', 1 ],
# [' doubleclick ',' Linkedin.com ', 2 ],
# [' doubleclick ',' ted.com ', 7 ],
# [' doubleclick ',' wot-top.ru ', 3 ],
# [' doubleclick ',' gislounge.com ', 13 ],
# [' doubleclick ',' darkstoorm.pl ', 1 ],
# [' doubleclick ',' finanology.co ', 2 ],
# [' doubleclick ',' ellomedia.de ', 1 ],
# [' doubleclick ',' witnessmyrage.com ', 4 ],
# [' doubleclick ',' divertir.eu ', 2 ],
# [' doubleclick ',' guterhut.de ', 1 ],
# [' doubleclick ',' rushtips.com ', 4 ],
# [' doubleclick ',' adhs-studien.info ', 1 ],
# [' doubleclick ',' campfyre.org ', 1 ],
# [' doubleclick ',' filedir.com ', 1 ],
# [' doubleclick ',' wallpaperme.de ', 7 ],
# [' doubleclick ',' ufsin.com ', 1 ],
# [' doubleclick ',' chroface.com ', 3 ],
# [' doubleclick ',' generadormemes.com ', 1 ],
# [' doubleclick ',' cameralabs.org ', 1 ],
# [' doubleclick ',' qnimate.com ', 1 ],
# [' doubleclick ',' wallpaper.dice4rich.com ', 1 ],
# [' doubleclick ',' allwomens.ru ', 3 ],
# [' doubleclick ',' gtacrazy.com ', 2 ],
# [' doubleclick ',' bentobyte.co ', 3 ],
# [' doubleclick ',' saludterapia.com ', 1 ],
# [' doubleclick ',' stefanschroeter.com ', 1 ],
# [' doubleclick ',' homebrewpower.co.uk ', 1 ],
# [' doubleclick ',' tomsk.stenagoroda.ru ', 1 ],
# [' doubleclick ',' androidfact.com ', 2 ],
# [' doubleclick ',' naveen.me ', 1 ],
# [' doubleclick ',' wiki.mikejung.biz ', 2 ],
# [' doubleclick ',' goldenline.pl ', 4 ],
# [' doubleclick ',' avtoed.com ', 1 ],
# [' doubleclick ',' jeanviet.info ', 7 ],
# [' doubleclick ',' newsburn.com ', 1 ],
# [' doubleclick ',' penserchanger.com ', 1 ],
# [' doubleclick ',' recetas-de-cocina-casera.com ', 2 ],
# [' doubleclick ',' Jmsima.com ', 2 ],
# [' doubleclick ',' jmsima.com ', 2 ],
# [' doubleclick ',' inforocked.com ', 3 ],
# [' doubleclick ',' blog.dashaft.net ', 3 ],
# [' doubleclick ',' london-life.ru ', 1 ],
# [' doubleclick ',' theloudlaugh.com ', 2 ],
# [' doubleclick ',' dejure.org ', 8 ],
# [' doubleclick ',' medien-internet-und-recht.de ', 2 ],
# [' doubleclick ',' socialsweethearts.de ', 5 ],
# [' doubleclick ',' steamcardexchange.net ', 1 ],
# [' doubleclick ',' Words Nouveau ', 1 ],
# [' doubleclick ',' secretoschile.cl ', 1 ],
# [' doubleclick ',' golfladders.co.uk ', 2 ],
# [' doubleclick ',' wallpapersimages.co.uk ', 3 ],
# [' doubleclick ',' Wood Fantasy ', 3 ],
# [' doubleclick ',' WebCofp ', 2 ],
# [' doubleclick ',' Bazwise Technology ', 4 ],
# [' doubleclick ',' designtagebuch.de ', 5 ],
# [' doubleclick ',' sparkylinux.org ', 2 ],
# [' doubleclick ',' nedvizhimostpro.kz ', 1 ],
# [' doubleclick ',' clipper.pada-x.com ', 2 ],
# [' doubleclick ',' hipkit.net ', 4 ],
# [' doubleclick ',' survoldefrance.fr ', 1 ],
# [' doubleclick ',' spooky.ru ', 4 ],
# [' doubleclick ',' house4u.com.ua ', 4 ],
# [' doubleclick ',' filmmusicsite.com ', 2 ],
# [' doubleclick ',' isot.me ', 2 ],
# [' doubleclick ',' bnet.cc ', 1 ],
# [' doubleclick ',' pozdravlandia.ru ', 2 ],
# [' doubleclick ',' pixelpeeper.com ', 3 ],
# [' doubleclick ',' bowl-of-soup.co.uk ', 2 ],
# [' doubleclick ',' forum.boypoint.de ', 4 ],
# [' doubleclick ',' garitv.eu ', 2 ],
# [' doubleclick ',' aprendresansfaim.com ', 3 ],
# [' doubleclick ',' linux-scout.de ', 3 ],
# [' doubleclick ',' alteroffice.pl ', 1 ],
# [' doubleclick ',' aquariophilie.org ', 4 ],
# [' doubleclick ',' sainte-rita.fr ', 3 ],
# [' doubleclick ',' elettronica.cc ', 5 ],
# [' doubleclick ',' cybo.com ', 5 ],
# [' doubleclick ',' Yieldlove GmbH ', 23 ],
# [' doubleclick ',' kak-svoimi-rukami.com ', 2 ],
# [' doubleclick ',' ark-survival.net ', 3 ],
# [' doubleclick ',' slideshare.net ', 2 ],
# [' doubleclick ',' haydayfr.com ', 2 ],
# [' doubleclick ',' gamesmelter.com ', 2 ],
# [' doubleclick ',' teplospec.com ', 3 ],
# [' doubleclick ',' vopvet.ru ', 2 ],
# [' doubleclick ',' kudrim.ru ', 3 ],
# [' doubleclick ',' NZZ Osterreich ', 1 ],
# [' doubleclick ',' sporcle.com ', 3 ],
# [' doubleclick ',' Orange ', 1 ],
# [' doubleclick ',' 01referencement.com ', 1 ],
# [' doubleclick ',' alexfbp.tk ', 1 ],
# [' doubleclick ',' couchwives.de ', 4 ],
# [' doubleclick ',' photoshophunt.com ', 1 ],
# [' doubleclick ',' electrodances.com ', 1 ],
# [' doubleclick ',' calendrier-scolaire.org ', 3 ],
# [' doubleclick ',' thevarsity.ca ', 2 ],
# [' doubleclick ',' energyauditorhq.com ', 2 ],
# [' doubleclick ',' Criteo ', 1 ],
# [' doubleclick ',' Curse ', 14 ],
# [' doubleclick ',' eventmanagerblog.com ', 1 ],
# [' doubleclick ',' Kummer und Oster GbR ', 35 ],
# [' doubleclick ',' hearthstonewiki.ru ', 2 ],
# [' doubleclick ',' developpez.com ', 1 ],
# [' doubleclick ',' free-blog.net ', 1 ],
# [' doubleclick ',' comuniogpstats.com ', 2 ],
# [' doubleclick ',' pinfruit.com ', 1 ],
# [' doubleclick ',' iscribble.net ', 1 ],
# [' doubleclick ',' add0n.com ', 4 ],
# [' doubleclick ',' informal.com.ua ', 2 ],
# [' doubleclick ',' driverlandia.com ', 1 ],
# [' doubleclick ',' freudenthal.biz ', 12 ],
# [' doubleclick ',' 01humours.com ', 3 ],
# [' doubleclick ',' bestblackfriday.com ', 5 ],
# [' doubleclick ',' Click Performance GmbH ', 3 ],
# [' doubleclick ',' studentdoctor.net ', 3 ],
# [' doubleclick ',' System1 parking ', 2 ],
# [' doubleclick ',' RevContent LLC ', 2 ],
# [' doubleclick ',' cuisinezpourvospapilles.fr ', 2 ],
# [' doubleclick ',' jesus-without-language.net ', 1 ],
# [' doubleclick ',' codemperium.com ', 1 ],
# [' doubleclick ',' googleentubolsillo.com ', 1 ],
# [' doubleclick ',' gettinggeek.com ', 3 ],
# [' doubleclick ',' xirion.net ', 1 ],
# [' doubleclick ',' androiduj.cz ', 4 ],
# [' doubleclick ',' profilepic.com ', 3 ],
# [' doubleclick ',' inforesist.org ', 4 ],
# [' doubleclick ',' diabeteschart.org ', 1 ],
# [' doubleclick ',' tecnologiasdeultimogrito.com ', 5 ],
# [' doubleclick ',' secondcasa.com ', 6 ],
# [' doubleclick ',' evileg.ru ads ', 13 ],
# [' doubleclick ',' blog.creativform.com ', 2 ],
# [' doubleclick ',' alqamoos.org ', 3 ],
# [' doubleclick ',' tripinfo.com ', 3 ],
# [' doubleclick ',' wows-mods.tk ', 1 ],
# [' doubleclick ',' gnetwork.eu ', 12 ],
# [' doubleclick ',' pianobuyer.com ', 1 ],
# [' doubleclick ',' torten-talk.de ', 3 ],
# [' doubleclick ',' veganforum.co.uk ', 2 ],
# [' doubleclick ',' kagns.ru ', 2 ],
# [' doubleclick ',' telearroba.es ', 4 ],
# [' doubleclick ',' green-arrow-france.fr ', 1 ],
# [' doubleclick ',' vesyolyikarandashik.ru ', 3 ],
# [' doubleclick ',' nonogramsonline.com ', 1 ],
# [' doubleclick ',' mirai.so ', 1 ],
# [' doubleclick ',' opengapps.org ', 2 ],
# [' doubleclick ',' nightearth.com ', 1 ],
# [' doubleclick ',' mundopepone.com ', 1 ],
# [' doubleclick ',' naturinspiriert.org ', 2 ],
# [' doubleclick ',' auto-karta-hrvatske.com ', 1 ],
# [' doubleclick ',' basemine.ru ', 2 ],
# [' doubleclick ',' skidanje-youtube-videa.com ', 5 ],
# [' doubleclick ',' apprendrelesolfege.com ', 2 ],
# [' doubleclick ',' 100let-bez-bed.ru ', 3 ],
# [' doubleclick ',' poroscience.com ', 3 ],
# [' doubleclick ',' tlv.buzz ', 1 ],
# [' doubleclick ',' galernayas.ru ', 1 ],
# [' doubleclick ',' androidcorps.com ', 5 ],
# [' doubleclick ',' nynno.com ', 1 ],
# [' doubleclick ',' grandoldteam.com ', 4 ],
# [' doubleclick ',' keengamer.com ', 4 ],
# [' doubleclick ',' yachts-boat.com ', 2 ],
# [' doubleclick ',' ros-bot.com ', 3 ],
# [' doubleclick ',' blog.guillaume-gomez.fr ', 1 ],
# [' doubleclick ',' expatriate.pl ', 2 ],
# [' doubleclick ',' strojar.com ', 2 ],
# [' doubleclick ',' pechenegfx.org ', 2 ],
# [' doubleclick ',' afterhoursprogramming.com ', 1 ],
# [' doubleclick ',' linuxquestions.org ', 1 ],
# [' doubleclick ',' stop-nepey.ru ', 3 ],
# [' doubleclick ',' looksharp.com ', 1 ],
# [' doubleclick ',' stephanearguin.com ', 1 ],
# [' doubleclick ',' btrans.by ', 1 ],
# [' doubleclick ',' cuve ', 2 ],
# [' doubleclick ',' Wykop Sp. z o.o. ', 3 ],
# [' doubleclick ',' dianomi ltd ', 4 ],
# [' doubleclick ',' tampermonkey.net ', 1 ],
# [' doubleclick ',' tech-alg.com ', 5 ],
# [' doubleclick ',' golocal.de ', 1 ],
# [' doubleclick ',' krasbaks.ru ', 1 ],
# [' doubleclick ',' speechtexter.com ', 1 ],
# [' doubleclick ',' kangsigit.com ', 4 ],
# [' doubleclick ',' abaixoassinado.org ', 4 ],
# [' doubleclick ',' datagame.su ', 3 ],
# [' doubleclick ',' spanishdict.com ', 7 ],
# [' doubleclick ',' pressfire.no ', 3 ],
# [' doubleclick ',' bandwagonbible.com ', 2 ],
# [' doubleclick ',' mig-welding.co.uk ', 1 ],
# [' doubleclick ',' avito.ru ', 3 ],
# [' doubleclick ',' kodi-xbmc.com ', 2 ],
# [' doubleclick ',' walkhighlands.co.uk ', 1 ],
# [' doubleclick ',' jeuxonline.info ', 5 ],
# [' doubleclick ',' 4cheat.ru ', 3 ],
# [' doubleclick ',' lamtrip.com ', 2 ],
# [' doubleclick ',' Smartology ', 1 ],
# [' doubleclick ',' zitate.net ', 5 ],
# [' doubleclick ',' kuduk.ru ', 2 ],
# [' doubleclick ',' routenplaner-kostenlos-24h.com ', 1 ],
# [' doubleclick ',' sysmasters.ne ', 2 ],
# [' doubleclick ',' selskaja-zhizn.ru ', 2 ],
# [' doubleclick ',' atr-nov.ru ', 2 ],
# [' doubleclick ',' windows-repair-toolbox.com ', 3 ],
# [' doubleclick ',' 4ege.ru ', 1 ],
# [' doubleclick ',' spravocnik.su ', 3 ],
# [' doubleclick ',' greatschools.org ', 8 ],
# [' doubleclick ',' trustmyscience.com ', 5 ],
# [' doubleclick ',' chelsea-balkan.com ', 1 ],
# [' doubleclick ',' lovenkiss.me ', 1 ],
# [' doubleclick ',' ausjeepoffroad.com ', 1 ],
# [' doubleclick ',' marcoweb.com.ve ', 3 ],
# [' doubleclick ',' autos.dp.ua ', 1 ],
# [' doubleclick ',' cmdrkeene.com ', 5 ],
# [' doubleclick ',' arzamas-city.ru ', 4 ],
# [' doubleclick ',' drive2.ru ', 9 ],
# [' doubleclick ',' finaltestman.de ', 1 ],
# [' doubleclick ',' Agora SA ', 6 ],
# [' doubleclick ',' workupload.com ', 3 ],
# [' doubleclick ',' maplorer.com ', 2 ],
# [' doubleclick ',' bizarrepedia.com ', 1 ],
# [' doubleclick ',' AdPushup ', 4 ],
# [' doubleclick ',' bedandchai.com ', 1 ],
# [' doubleclick ',' kevera.com ', 1 ],
# [' doubleclick ',' appsapk.com ', 2 ],
# [' doubleclick ',' freedirectorywebsites.com ', 4 ],
# [' doubleclick ',' itservicesthatworkforyou.com ', 1 ],
# [' doubleclick ',' ccnahub.com ', 4 ],
# [' doubleclick ',' danka.com.ua ', 1 ],
# [' doubleclick ',' lnindo.com ', 2 ],
# [' doubleclick ',' survarium.pro ', 3 ],
# [' doubleclick ',' bokas.info ', 5 ],
# [' doubleclick ',' diffnow.com ', 2 ],
# [' doubleclick ',' integralrechner.de ', 18 ],
# [' doubleclick ',' pro-vst.org ', 1 ],
# [' doubleclick ',' unsacsurledos.com ', 2 ],
# [' doubleclick ',' tgspot.co.il ', 1 ],
# [' doubleclick ',' toolslib.net ', 3 ],
# [' doubleclick ',' unfassbar.es ', 3 ],
# [' doubleclick ',' hipertextual.com ', 1 ],
# [' doubleclick ',' bk-works.net ', 1 ],
# [' doubleclick ',' ZureCraft ', 2 ],
# [' doubleclick ',' 4gnews.pt ', 4 ],
# [' doubleclick ',' lancejames.tk ', 2 ],
# [' doubleclick ',' wingeno.org ', 1 ],
# [' doubleclick ',' jeuxclic.com ', 16 ],
# [' doubleclick ',' ankitupadhyay.com ', 2 ],
# [' doubleclick ',' Sibbo Ventures ', 7 ],
# [' doubleclick ',' marketharborough.com ', 1 ],
# [' doubleclick ',' Fotostrana ', 2 ],
# [' doubleclick ',' ket-noi.com ', 2 ],
# [' doubleclick ',' winshell.org ', 1 ],
# [' doubleclick ',' networkdirection.net ', 2 ],
# [' doubleclick ',' bookinist.com.ua ', 1 ],
# [' doubleclick ',' hundeerlaubt.de ', 4 ],
# [' doubleclick ',' selectparkhomes.com ', 1 ],
# [' doubleclick ',' for-pcs.com ', 5 ],
# [' doubleclick ',' krachtforum.nl ', 1 ],
# [' doubleclick ',' replayswows.ru ', 2 ],
# [' doubleclick ',' manualslib.com ', 3 ],
# [' doubleclick ',' cageek.com.mx ', 1 ],
# [' doubleclick ',' brchart.tk ', 1 ],
# [' doubleclick ',' blog.curiosoinformatico.com ', 1 ],
# [' doubleclick ',' mfoxes.net ', 1 ],
# [' doubleclick ',' speedycppshq.com ', 1 ],
# [' doubleclick ',' linuxthebest.net ', 3 ],
# [' doubleclick ',' dance-charts.de ', 2 ],
# [' doubleclick ',' hohle-der-lowen.com ', 2 ],
# [' doubleclick ',' chinesetools.eu ', 1 ],
# [' doubleclick ',' online2pdf.com ', 4 ],
# [' doubleclick ',' chine.in ', 1 ],
# [' doubleclick ',' bitchop.net ', 1 ],
# [' doubleclick ',' cbanque.com ', 2 ],
# [' doubleclick ',' Wequizs.com ', 2 ],
# [' doubleclick ',' Tightrope Interactive ', 12 ],
# [' doubleclick ',' fileford.com ', 2 ],
# [' doubleclick ',' onlinetradingconcepts.com ', 2 ],
# [' doubleclick ',' vperedi.ru ', 1 ],
# [' doubleclick ',' bouwsteentjes.info ', 1 ],
# [' doubleclick ',' unepetition.fr ', 3 ],
# [' doubleclick ',' blog.franmoreno.me ', 1 ],
# [' doubleclick ',' dgameclub.com ', 1 ],
# [' doubleclick ',' hilferuf.de ', 2 ],
# [' doubleclick ',' OLX Poland Naspers Classifieds ', 5 ],
# [' doubleclick ',' weeklycomputingidea.blogspot.com ', 1 ],
# [' doubleclick ',' polskastrefa.pl ', 1 ],
# [' doubleclick ',' jsmaps.io ', 3 ],
# [' doubleclick ',' menginspirasi.com ', 2 ],
# [' doubleclick ',' symvolinews.gr ', 2 ],
# [' doubleclick ',' casinuevo.com ', 4 ],
# [' doubleclick ',' system-kanban.pl ', 3 ],
# [' doubleclick ',' authenticspirit.fr ', 3 ],
# [' doubleclick ',' trackingthepros.com ', 1 ],
# [' doubleclick ',' i-dont-care-about-cookies.eu ', 1 ],
# [' doubleclick ',' it-like.ru ', 4 ],
# [' doubleclick ',' brightadvise.com ', 2 ],
# [' doubleclick ',' Grupa ZPR ', 2 ],
# [' doubleclick ',' perguntedireito.com.br ', 2 ],
# [' doubleclick ',' istiller.com ', 2 ],
# [' doubleclick ',' typo3forum.net ', 2 ],
# [' doubleclick ',' Softonic ', 12 ],
# [' doubleclick ',' camel.co.il ', 2 ],
# [' doubleclick ',' tylife.github.io ', 2 ],
# [' doubleclick ',' coffeetime.solutions ', 1 ],
# [' doubleclick ',' beauvais.me ', 3 ],
# [' doubleclick ',' alilove.pl ', 3 ],
# [' doubleclick ',' IPONWEB limited ', 2 ],
# [' doubleclick ',' download-zone7.blogspot.com ', 1 ],
# [' doubleclick ',' mabandepassante.com ', 1 ],
# [' doubleclick ',' mafojobs.de ', 3 ],
# [' doubleclick ',' gondolathief.com ', 2 ],
# [' doubleclick ',' buzer.de ', 1 ],
# [' doubleclick ',' belote-coinchee.net ', 1 ],
# [' doubleclick ',' fitnessrezepte.de ', 1 ],
# [' doubleclick ',' anyaplanet.net ', 1 ],
# [' doubleclick ',' vie-naturelle.info ', 3 ],
# [' doubleclick ',' thecrimson.com ', 1 ],
# [' doubleclick ',' fbgamesgifts.com ', 1 ],
# [' doubleclick ',' adtechdaily.com ', 9 ],
# [' doubleclick ',' AdTaily Group ', 2 ],
# [' doubleclick ',' gamesflow.com ', 10 ],
# [' doubleclick ',' Polskapress ', 5 ],
# [' doubleclick ',' OLX Global B.V. ', 5 ],
# [' doubleclick ',' rimessolides.com ', 1 ],
# [' doubleclick ',' HABR LLC ', 1 ],
# [' doubleclick ',' digireality.cz ', 1 ],
# [' doubleclick ',' VK ', 1 ],
# [' doubleclick ',' ppc.world ', 1 ],
# [' doubleclick ',' seoseoseo.it ', 1 ],
# [' doubleclick ',' saznajnovo.com ', 2 ],
# [' doubleclick ',' samsungdeodex.com ', 1 ],
# [' doubleclick ',' sammdex.com ', 1 ],
# [' doubleclick ',' GG Software ', 1 ],
# [' doubleclick ',' bestecode.com ', 1 ],
# [' doubleclick ',' Bonnier.pl ', 1 ],
# [' doubleclick ',' shortorial.com ', 1 ],
# [' doubleclick ',' moviescout.org ', 1 ],
# [' doubleclick ',' cienciaglobal.com ', 1 ],
# [' doubleclick ',' Google ', 5 ],
# [' doubleclick ',' Tradedoubler ', 7 ],
# [' doubleclick ',' AAX ', 1 ],
# [' doubleclick ',' Oath ', 1 ],
# [' criteo ',' Taboola ', 4 ],
# [' criteo ',' Yieldlove GmbH ', 3 ],
# [' criteo ',' Criteo ', 390 ],
# [' criteo ',' bestblackfriday.com ', 1 ],
# [' criteo ',' RevContent LLC ', 1 ],
# [' criteo ',' Agora SA ', 1 ],
# [' criteo ',' Polskapress ', 2 ],
# [' criteo ',' VK ', 2 ],
# [' criteo ',' AAX ', 2 ],
# [' criteo ',' Oath ', 1 ],
# [' criteo ',' tumblr.com ', 1 ],
# [' yandex ',' droidmid.com.ua ', 3 ],
# [' yandex ',' pervushin.com ', 3 ],
# [' yandex ',' mamapages.ru ', 3 ],
# [' yandex ',' domikdom.ru ', 3 ],
# [' yandex ',' comunicom.ru ', 3 ],
# [' yandex ',' joofaq.ru ', 3 ],
# [' yandex ',' koleso-sovetsk.ru ', 3 ],
# [' yandex ',' Yandex ', 3 ],
# [' yandex ',' freesp.ru ', 3 ],
# [' yandex ',' hummerclubrus.ru ', 3 ],
# [' yandex ',' coonplace.ru ', 3 ],
# [' yandex ',' Trainphoto.org.ua ', 3 ],
# [' yandex ',' arttime.org.ua ', 3 ],
# [' yandex ',' hdtrailer.ru ', 3 ],
# [' yandex ',' seoslim.ru ', 3 ],
# [' yandex ',' magiachisel.ru ', 3 ],
# [' yandex ',' forum.vseoglazah.ru ', 3 ],
# [' yandex ',' and-berd ', 3 ],
# [' yandex ',' kupidom2.com ', 3 ],
# [' yandex ',' moda4u.com.ua ', 3 ],
# [' yandex ',' glavpoezdrus.ru ', 3 ],
# [' yandex ',' medspecial.ru ', 5 ],
# [' yandex ',' math1.ru ', 4 ],
# [' yandex ',' zrenue.com ads ', 3 ],
# [' yandex ',' fincalculator.ru ', 3 ],
# [' yandex ',' doorinworld.ru ', 3 ],
# [' yandex ',' korenovsk.net ', 3 ],
# [' yandex ',' mishred.ru ', 3 ],
# [' yandex ',' bestru.ru ', 3 ],
# [' yandex ',' cameralabs.org ', 3 ],
# [' yandex ',' allwomens.ru ', 3 ],
# [' yandex ',' avtoed.com ', 3 ],
# [' yandex ',' london-life.ru ', 3 ],
# [' yandex ',' avito.kz ', 3 ],
# [' yandex ',' nedvizhimostpro.kz ', 3 ],
# [' yandex ',' pozdravlandia.ru ', 6 ],
# [' yandex ',' muzei-mira.com ', 3 ],
# [' yandex ',' baby-health.info ', 3 ],
# [' yandex ',' sitehere.ru ', 3 ],
# [' yandex ',' temowind.ru ', 3 ],
# [' yandex ',' vasilisc.com ', 3 ],
# [' yandex ',' evileg.ru ads ', 4 ],
# [' yandex ',' infaplus.ru ', 3 ],
# [' yandex ',' galernayas.ru ', 3 ],
# [' yandex ',' avito.ru ', 7 ],
# [' yandex ',' habit.ru ', 3 ],
# [' yandex ',' 4ege.ru ', 3 ],
# [' yandex ',' arzamas-city.ru ', 4 ],
# [' yandex ',' drive2.ru ', 4 ],
# [' yandex ',' obzorka.net ', 4 ],
# [' yandex ',' Fotostrana ', 6 ],
# [' yandex ',' allremont59.ru ', 5 ],
# [' yandex ',' pixmafia.com ', 5 ],
# [' yandex ',' kto-irkutsk.ru ', 4 ],
# [' yandex ',' record-russia.ru ', 4 ],
# [' yandex ',' anyaplanet.net ', 4 ],
# [' yandex ',' express-novosti.ru ', 5 ],
# [' googlesyndication ',' BuySellAds ', 1 ],
# [' googlesyndication ',' 1und1 Mail und Media GmbH ', 1 ],
# [' googlesyndication ',' heise.de ', 1 ],
# [' googlesyndication ',' SimilarGroup ', 1 ],
# [' googlesyndication ',' Leaf Group Ltd. ', 3 ],
# [' googlesyndication ',' computerbase.de ', 1 ],
# [' googlesyndication ',' Chip.de ', 1 ],
# [' googlesyndication ',' Reverso ', 4 ],
# [' googlesyndication ',' t3n.de ', 1 ],
# [' googlesyndication ',' CCM Benchmark Group ', 1 ],
# [' googlesyndication ',' Gamer Network ', 2 ],
# [' googlesyndication ',' ted.com ', 3 ],
# [' googlesyndication ',' guterhut.de ', 1 ],
# [' googlesyndication ',' rushtips.com ', 2 ],
# [' googlesyndication ',' Yieldlove GmbH ', 4 ],
# [' googlesyndication ',' thevarsity.ca ', 2 ],
# [' googlesyndication ',' Curse ', 2 ],
# [' googlesyndication ',' eventmanagerblog.com ', 1 ],
# [' googlesyndication ',' studentdoctor.net ', 2 ],
# [' googlesyndication ',' pianobuyer.com ', 1 ],
# [' googlesyndication ',' looksharp.com ', 2 ],
# [' googlesyndication ',' avito.ru ', 2 ],
# [' googlesyndication ',' greatschools.org ', 2 ],
# [' googlesyndication ',' Agora SA ', 3 ],
# [' googlesyndication ',' AdPushup ', 6 ],
# [' googlesyndication ',' tgspot.co.il ', 1 ],
# [' googlesyndication ',' Sibbo Ventures ', 1 ],
# [' googlesyndication ',' Fotostrana ', 1 ],
# [' googlesyndication ',' OLX Poland Naspers Classifieds ', 2 ],
# [' googlesyndication ',' Blockthrough Inc. ', 2 ],
# [' googlesyndication ',' Softonic ', 3 ],
# [' googlesyndication ',' IPONWEB limited ', 1 ],
# [' googlesyndication ',' mafojobs.de ', 2 ],
# [' googlesyndication ',' thecrimson.com ', 3 ],
# [' googlesyndication ',' adtechdaily.com ', 3 ],
# [' googlesyndication ',' AdTaily Group ', 1 ],
# [' googlesyndication ',' gamesflow.com ', 1 ],
# [' googlesyndication ',' Polskapress ', 4 ],
# [' googlesyndication ',' OLX Global B.V. ', 1 ],
# [' googlesyndication ',' HABR LLC ', 3 ],
# [' googlesyndication ',' saznajnovo.com ', 1 ],
# [' googlesyndication ',' GG Software ', 1 ],
# [' googlesyndication ',' Bonnier.pl ', 1 ],
# [' googlesyndication ',' Google ', 5 ],
# [' googlesyndication ',' Tradedoubler ', 18 ],
